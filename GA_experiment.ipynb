# %% [markdown]
# ### Imports

# %%
import subprocess
import os
# from unlearning_metrics.evaluate.config import parameters
from config import parameters
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt


from models.archs.ConvNet import ConvNet
from config import parameters
from unlearn.GA import GA
from data.utils import get_unlearn_loader, setup_model_dataset, accuracy
from trainer.utils import get_memory_footprint, get_model_weight_norm, check_accuracy
parameters["seed"] = 42

# %% [markdown]
# ### Data loaders

# %%
from torchvision.utils import make_grid
# # ... define a dataset, forget set, and retain set
train_full_loader, val_loader, test_loader, marked_loader = setup_model_dataset(args = parameters)
forget_loader, retain_loader = get_unlearn_loader(marked_loader = marked_loader, args = parameters)

X, y = next(iter(train_full_loader))
plt.figure(figsize=(18,10))
plt.imshow(make_grid(X, nrow=10).permute((1,2,0)));
# Out:
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# /opt/miniconda3/envs/comp0081/lib/python3.12/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.4290657..2.7537313].
# datasets length:  4500 40500

# %% [markdown]
# ### Test Base model on Data loaders

# %% [markdown]
# ### The Unlearning regimen

# %%
import json
import numpy as np

def unlearn_regimen(model, forget_loader, retain_loader, num_epochs, criterion, optimizer, print_freq, measure_every, device, name = "run_1", save_folder = "results"):

    # create save folder if it doesn't exist
    if not os.path.exists(save_folder):
        print(f"{save_folder} doesn't exist - creating it...")
        os.makedirs(save_folder, exist_ok=True)

    # track initial results
    forget_acc = check_accuracy(model, data_loader = forget_loader, device = device)
    retain_acc = check_accuracy(model, data_loader = retain_loader, device = device)
    print(f"Baseline | Forget Set Accuracy: {forget_acc:.2f} | Retain Set Accuracy: {retain_acc:.2f}")

    # For each epoch ...
    for k in range(1, num_epochs+1):

        # ... do one round of GA,
        model, top1_avg = GA(forget_loader, model, criterion, optimizer, epoch = k, print_freq = print_freq, device = device)

        # ... eval on forget set and retain set
        forget_acc = check_accuracy(model, data_loader = forget_loader, device = device)
        retain_acc = check_accuracy(model, data_loader = retain_loader, device = device)
        test_acc = check_accuracy(model, data_loader = test_loader, device = device)
        print(f"Epoch: {k} | Forget Set Accuracy: {forget_acc:.3f} | Retain Set Accuracy: {retain_acc:.3f} | Test Set Accuracy: {test_acc:.3f}\n")

        # ... and if we're saving out,
        if k % measure_every == 0:
            
            # ... create an epoch-level subfolder if it doesn't exist
            epoch_save_folder = os.path.join(save_folder, f"epoch_{k}")
            if not os.path.exists(epoch_save_folder):   
                print(f"{epoch_save_folder} doesn't exist - creating it...")
                os.makedirs(epoch_save_folder, exist_ok=True)
            
            # ... bind results to a dictionary,
            results = {
                "name": name,
                "epoch": k,
                "forget_acc": forget_acc,
                "retain_acc": retain_acc,
                "test_acc": test_acc,
                "top1_avg": top1_avg
            }

            # ... and save them
            with open(os.path.join(epoch_save_folder, f"{name}.json"), "w") as f:
                json.dump(results, f, indent=4)

    return model

# %% [markdown]
# ### Run it

# %%
import random

def group_runs(seed = 42, num_runs_each = 2, num_epochs = 20, measure_every = 2, main_folder = "results"):

    # apply seed to params, so all downstream functions can use it
    parameters["seed"] = seed

    # Make folder if it doesnt already exist
    if not os.path.exists(main_folder):
        print(f"{main_folder} doesn't exist - creating it...")
        os.makedirs(main_folder, exist_ok=True)

    # Save the config for this run to the main folder
    ULR = 3e-6 # this is a good one for the full regime
    # ULR = 5e-6 # this is a good one for a quick test run
    run_config = {
        "num_runs_each": num_runs_each,
        "num_epochs": num_epochs,
        "measure_every": measure_every,
        "ULR": ULR
    }
    with open(os.path.join(main_folder, "config.json"), "w") as f:
        json.dump(run_config, f, indent=4)

    # For each class ...
    for c in range(0, 10):

        print("="*50 + "    " + f"CLASS {c}\n")

        #... assign it as class to forget
        parameters["class_to_replace"] = c
        print(f"Class to forget for this run: {c}\n")

        # ... and do some number of runs, where
        for i in range(1, num_runs_each+1):

            print("-"*25 + "    " + f"RUN {i}\n")
            run_name = f"class_{c}_run_{i}"

            # ... load a model checkpoint from which to begin unlearning
            device = torch.device("mps") if torch.mps.is_available() else torch.device("cpu")
            base_model = ConvNet()
            checkpoint = torch.load("models/model_checkpoints/ConvNet_CIFAR10_2026-03-17.pth")
            base_model.load_state_dict(checkpoint["model_state_dict"])
            base_model.to(device)
        
            # ... define data loaders w.r.t. class to forget
            # ----- we are deliberately defining these inside the loop, so that they are refreshed for each run, hence more random
            train_full_loader, val_loader, test_loader, marked_loader = setup_model_dataset(args = parameters)
            forget_loader, retain_loader = get_unlearn_loader(marked_loader = marked_loader, args = parameters)
            
            # ... define params
            opt = optim.Adam(base_model.parameters(), lr=ULR)
            criterion = nn.CrossEntropyLoss()

            # ... and run the unlearning regimen
            _ = unlearn_regimen(base_model, forget_loader, retain_loader, num_epochs, criterion, opt, print_freq = 15, measure_every = measure_every, device = device, name = run_name, save_folder = main_folder)

# %%
# MAKE A RANDOM SEED
seed = 22
# DO EXP
group_runs(seed = seed, num_runs_each = 10, num_epochs = 12, measure_every=1, main_folder = f"results/seed_{seed}")
# Out:
# ==================================================    CLASS 0
#
# Class to forget for this run: 0
#
# -------------------------    RUN 1
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# /opt/miniconda3/envs/comp0081/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# Baseline | Forget Set Accuracy: 0.93 | Retain Set Accuracy: 0.93
# Epoch: [1][0/36]	Loss -0.3329 (-0.3329)	Accuracy 88.281 (88.281)	Time 0.34
# Epoch: [1][15/36]	Loss -0.2832 (-0.2770)	Accuracy 90.625 (90.527)	Time 1.16
# Epoch: [1][30/36]	Loss -0.3051 (-0.2959)	Accuracy 88.281 (90.297)	Time 1.10
# Epoch: 1 | Forget Set Accuracy: 0.880 | Retain Set Accuracy: 0.928 | Test Set Accuracy: 0.866
#
# Epoch: [2][0/36]	Loss -0.4051 (-0.4051)	Accuracy 87.500 (87.500)	Time 0.37
# Epoch: [2][15/36]	Loss -0.3630 (-0.3941)	Accuracy 85.156 (86.328)	Time 1.18
# Epoch: [2][30/36]	Loss -0.5973 (-0.4221)	Accuracy 77.344 (85.433)	Time 1.03
# Epoch: 2 | Forget Set Accuracy: 0.818 | Retain Set Accuracy: 0.928 | Test Set Accuracy: 0.868
#
# Epoch: [3][0/36]	Loss -0.4298 (-0.4298)	Accuracy 84.375 (84.375)	Time 0.44
# Epoch: [3][15/36]	Loss -0.6800 (-0.5872)	Accuracy 77.344 (80.811)	Time 1.32
# Epoch: [3][30/36]	Loss -0.9150 (-0.6628)	Accuracy 72.656 (78.780)	Time 1.17
# Epoch: 3 | Forget Set Accuracy: 0.725 | Retain Set Accuracy: 0.925 | Test Set Accuracy: 0.867
#
# results/seed_22/epoch_3 doesn't exist - creating it...
# Epoch: [4][0/36]	Loss -0.9903 (-0.9903)	Accuracy 71.094 (71.094)	Time 0.36
# Epoch: [4][15/36]	Loss -1.0523 (-0.9480)	Accuracy 71.875 (70.752)	Time 1.38
# Epoch: [4][30/36]	Loss -1.4511 (-1.0741)	Accuracy 64.844 (67.389)	Time 1.14
# Epoch: 4 | Forget Set Accuracy: 0.606 | Retain Set Accuracy: 0.923 | Test Set Accuracy: 0.866
#
# results/seed_22/epoch_4 doesn't exist - creating it...
# Epoch: [5][0/36]	Loss -1.4370 (-1.4370)	Accuracy 64.062 (64.062)	Time 0.41
# Epoch: [5][15/36]	Loss -1.7549 (-1.5025)	Accuracy 50.000 (57.275)	Time 1.15
# Epoch: [5][30/36]	Loss -1.7123 (-1.6611)	Accuracy 51.562 (54.410)	Time 1.00
# Epoch: 5 | Forget Set Accuracy: 0.458 | Retain Set Accuracy: 0.917 | Test Set Accuracy: 0.864
#
# results/seed_22/epoch_5 doesn't exist - creating it...
# Epoch: [6][0/36]	Loss -2.3372 (-2.3372)	Accuracy 44.531 (44.531)	Time 0.34
# Epoch: [6][15/36]	Loss -2.6424 (-2.3536)	Accuracy 37.500 (42.725)	Time 1.05
# Epoch: [6][30/36]	Loss -3.0930 (-2.5293)	Accuracy 34.375 (40.247)	Time 1.15
# Epoch: 6 | Forget Set Accuracy: 0.320 | Retain Set Accuracy: 0.913 | Test Set Accuracy: 0.860
#
# results/seed_22/epoch_6 doesn't exist - creating it...
# Epoch: [7][0/36]	Loss -3.2691 (-3.2691)	Accuracy 28.906 (28.906)	Time 0.43
# Epoch: [7][15/36]	Loss -3.0880 (-3.4579)	Accuracy 35.156 (28.125)	Time 1.12
# Epoch: [7][30/36]	Loss -4.2582 (-3.7661)	Accuracy 21.875 (25.958)	Time 0.98
# Epoch: 7 | Forget Set Accuracy: 0.185 | Retain Set Accuracy: 0.903 | Test Set Accuracy: 0.853
#
# results/seed_22/epoch_7 doesn't exist - creating it...
# Epoch: [8][0/36]	Loss -4.4664 (-4.4664)	Accuracy 19.531 (19.531)	Time 0.32
# Epoch: [8][15/36]	Loss -5.4510 (-5.0327)	Accuracy 12.500 (15.674)	Time 1.13
# Epoch: [8][30/36]	Loss -6.1516 (-5.3814)	Accuracy 10.156 (14.441)	Time 1.07
# Epoch: 8 | Forget Set Accuracy: 0.094 | Retain Set Accuracy: 0.886 | Test Set Accuracy: 0.841
#
# results/seed_22/epoch_8 doesn't exist - creating it...
# Epoch: [9][0/36]	Loss -5.8897 (-5.8897)	Accuracy 13.281 (13.281)	Time 0.36
# Epoch: [9][15/36]	Loss -7.7788 (-6.8784)	Accuracy 4.688 (8.301)	Time 1.23
# Epoch: [9][30/36]	Loss -7.9571 (-7.2897)	Accuracy 5.469 (6.981)	Time 1.20
# Epoch: 9 | Forget Set Accuracy: 0.036 | Retain Set Accuracy: 0.870 | Test Set Accuracy: 0.826
#
# results/seed_22/epoch_9 doesn't exist - creating it...
# Epoch: [10][0/36]	Loss -8.5306 (-8.5306)	Accuracy 3.125 (3.125)	Time 0.44
# Epoch: [10][15/36]	Loss -9.0851 (-8.9416)	Accuracy 4.688 (2.881)	Time 1.26
# Epoch: [10][30/36]	Loss -9.7634 (-9.4009)	Accuracy 3.125 (2.571)	Time 1.16
# Epoch: 10 | Forget Set Accuracy: 0.012 | Retain Set Accuracy: 0.847 | Test Set Accuracy: 0.806
#
# results/seed_22/epoch_10 doesn't exist - creating it...
# Epoch: [11][0/36]	Loss -10.5297 (-10.5297)	Accuracy 0.781 (0.781)	Time 0.42
# Epoch: [11][15/36]	Loss -11.7245 (-11.3730)	Accuracy 0.781 (1.025)	Time 1.25
# Epoch: [11][30/36]	Loss -12.4928 (-11.8827)	Accuracy 0.000 (0.605)	Time 1.17
# Epoch: 11 | Forget Set Accuracy: 0.003 | Retain Set Accuracy: 0.812 | Test Set Accuracy: 0.780
#
# results/seed_22/epoch_11 doesn't exist - creating it...
# Epoch: [12][0/36]	Loss -13.9125 (-13.9125)	Accuracy 0.000 (0.000)	Time 0.40
# Epoch: [12][15/36]	Loss -14.3130 (-13.9134)	Accuracy 0.000 (0.146)	Time 1.23
# Epoch: [12][30/36]	Loss -15.6812 (-14.5335)	Accuracy 0.000 (0.101)	Time 1.16
# Epoch: 12 | Forget Set Accuracy: 0.000 | Retain Set Accuracy: 0.767 | Test Set Accuracy: 0.744
#
# results/seed_22/epoch_12 doesn't exist - creating it...
# -------------------------    RUN 2
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.92 | Retain Set Accuracy: 0.93
# Epoch: [1][0/36]	Loss -0.1268 (-0.1268)	Accuracy 96.094 (96.094)	Time 0.10
# Epoch: [1][15/36]	Loss -0.2633 (-0.2837)	Accuracy 89.844 (90.771)	Time 1.20
# Epoch: [1][30/36]	Loss -0.3595 (-0.3077)	Accuracy 85.156 (89.541)	Time 1.16
# Epoch: 1 | Forget Set Accuracy: 0.882 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.865
#
# Epoch: [2][0/36]	Loss -0.5402 (-0.5402)	Accuracy 80.469 (80.469)	Time 0.34
# Epoch: [2][15/36]	Loss -0.3150 (-0.4132)	Accuracy 89.844 (86.572)	Time 1.11
# Epoch: [2][30/36]	Loss -0.5719 (-0.4538)	Accuracy 79.688 (85.081)	Time 1.17
# Epoch: 2 | Forget Set Accuracy: 0.815 | Retain Set Accuracy: 0.928 | Test Set Accuracy: 0.868
#
# Epoch: [3][0/36]	Loss -0.5886 (-0.5886)	Accuracy 77.344 (77.344)	Time 0.19
# Epoch: [3][15/36]	Loss -0.7035 (-0.6049)	Accuracy 82.031 (80.176)	Time 1.05
# Epoch: [3][30/36]	Loss -0.7605 (-0.6574)	Accuracy 75.781 (78.503)	Time 1.08
# Epoch: 3 | Forget Set Accuracy: 0.726 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.867
#
# Epoch: [4][0/36]	Loss -0.7187 (-0.7187)	Accuracy 77.344 (77.344)	Time 0.43
# Epoch: [4][15/36]	Loss -1.0731 (-1.0049)	Accuracy 65.625 (68.896)	Time 1.15
# Epoch: [4][30/36]	Loss -1.4169 (-1.0705)	Accuracy 60.938 (67.288)	Time 1.03
# Epoch: 4 | Forget Set Accuracy: 0.605 | Retain Set Accuracy: 0.923 | Test Set Accuracy: 0.866
#
# Epoch: [5][0/36]	Loss -1.4966 (-1.4966)	Accuracy 62.500 (62.500)	Time 0.45
# Epoch: [5][15/36]	Loss -1.1555 (-1.4850)	Accuracy 64.062 (57.471)	Time 1.12
# Epoch: [5][30/36]	Loss -1.9045 (-1.6494)	Accuracy 43.750 (53.906)	Time 1.12
# Epoch: 5 | Forget Set Accuracy: 0.460 | Retain Set Accuracy: 0.918 | Test Set Accuracy: 0.863
#
# Epoch: [6][0/36]	Loss -2.2658 (-2.2658)	Accuracy 41.406 (41.406)	Time 0.46
# Epoch: [6][15/36]	Loss -2.2334 (-2.2475)	Accuracy 42.188 (43.701)	Time 1.06
# Epoch: [6][30/36]	Loss -3.0530 (-2.5078)	Accuracy 37.500 (40.020)	Time 1.00
# Epoch: 6 | Forget Set Accuracy: 0.327 | Retain Set Accuracy: 0.914 | Test Set Accuracy: 0.860
#
# Epoch: [7][0/36]	Loss -2.7451 (-2.7451)	Accuracy 32.812 (32.812)	Time 0.14
# Epoch: [7][15/36]	Loss -3.4178 (-3.4002)	Accuracy 28.125 (29.834)	Time 1.02
# Epoch: [7][30/36]	Loss -4.2709 (-3.7348)	Accuracy 23.438 (26.663)	Time 1.08
# Epoch: 7 | Forget Set Accuracy: 0.187 | Retain Set Accuracy: 0.900 | Test Set Accuracy: 0.852
#
# Epoch: [8][0/36]	Loss -4.8238 (-4.8238)	Accuracy 19.531 (19.531)	Time 0.31
# Epoch: [8][15/36]	Loss -5.7490 (-5.0870)	Accuracy 8.594 (15.527)	Time 1.19
# Epoch: [8][30/36]	Loss -5.7482 (-5.3767)	Accuracy 9.375 (14.088)	Time 1.09
# Epoch: 8 | Forget Set Accuracy: 0.093 | Retain Set Accuracy: 0.886 | Test Set Accuracy: 0.840
#
# Epoch: [9][0/36]	Loss -6.7488 (-6.7488)	Accuracy 7.031 (7.031)	Time 0.34
# Epoch: [9][15/36]	Loss -7.2555 (-6.8839)	Accuracy 4.688 (7.227)	Time 1.23
# Epoch: [9][30/36]	Loss -8.0081 (-7.2605)	Accuracy 5.469 (6.351)	Time 1.17
# Epoch: 9 | Forget Set Accuracy: 0.035 | Retain Set Accuracy: 0.869 | Test Set Accuracy: 0.825
#
# Epoch: [10][0/36]	Loss -8.6590 (-8.6590)	Accuracy 3.906 (3.906)	Time 0.35
# Epoch: [10][15/36]	Loss -10.1268 (-8.9310)	Accuracy 2.344 (3.369)	Time 1.19
# Epoch: [10][30/36]	Loss -10.6909 (-9.4520)	Accuracy 0.781 (2.671)	Time 1.25
# Epoch: 10 | Forget Set Accuracy: 0.014 | Retain Set Accuracy: 0.844 | Test Set Accuracy: 0.805
#
# Epoch: [11][0/36]	Loss -10.0202 (-10.0202)	Accuracy 3.906 (3.906)	Time 0.33
# Epoch: [11][15/36]	Loss -11.4608 (-11.4515)	Accuracy 0.000 (1.025)	Time 1.20
# Epoch: [11][30/36]	Loss -11.6922 (-11.8416)	Accuracy 0.781 (0.907)	Time 1.16
# Epoch: 11 | Forget Set Accuracy: 0.003 | Retain Set Accuracy: 0.811 | Test Set Accuracy: 0.776
#
# Epoch: [12][0/36]	Loss -13.7158 (-13.7158)	Accuracy 0.000 (0.000)	Time 0.25
# Epoch: [12][15/36]	Loss -14.0454 (-14.0600)	Accuracy 0.000 (0.244)	Time 1.35
# Epoch: [12][30/36]	Loss -16.2310 (-14.6345)	Accuracy 0.000 (0.151)	Time 1.16
# Epoch: 12 | Forget Set Accuracy: 0.001 | Retain Set Accuracy: 0.760 | Test Set Accuracy: 0.738
#
# -------------------------    RUN 3
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.92 | Retain Set Accuracy: 0.93
# Epoch: [1][0/36]	Loss -0.2568 (-0.2568)	Accuracy 92.969 (92.969)	Time 0.17
# Epoch: [1][15/36]	Loss -0.3105 (-0.2745)	Accuracy 91.406 (90.576)	Time 1.33
# Epoch: [1][30/36]	Loss -0.3350 (-0.3001)	Accuracy 85.938 (89.819)	Time 1.12
# Epoch: 1 | Forget Set Accuracy: 0.877 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.866
#
# Epoch: [2][0/36]	Loss -0.2520 (-0.2520)	Accuracy 90.625 (90.625)	Time 0.14
# Epoch: [2][15/36]	Loss -0.4598 (-0.3935)	Accuracy 85.938 (86.816)	Time 1.05
# Epoch: [2][30/36]	Loss -0.4675 (-0.4346)	Accuracy 83.594 (85.635)	Time 1.08
# Epoch: 2 | Forget Set Accuracy: 0.814 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.868
#
# Epoch: [3][0/36]	Loss -0.5565 (-0.5565)	Accuracy 84.375 (84.375)	Time 0.11
# Epoch: [3][15/36]	Loss -0.4303 (-0.5852)	Accuracy 85.156 (80.322)	Time 1.11
# Epoch: [3][30/36]	Loss -0.8935 (-0.6551)	Accuracy 72.656 (77.949)	Time 1.25
# Epoch: 3 | Forget Set Accuracy: 0.724 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.867
#
# Epoch: [4][0/36]	Loss -1.1382 (-1.1382)	Accuracy 65.625 (65.625)	Time 0.12
# Epoch: [4][15/36]	Loss -1.0206 (-0.8980)	Accuracy 68.750 (71.484)	Time 0.99
# Epoch: [4][30/36]	Loss -1.2095 (-1.0499)	Accuracy 60.156 (68.019)	Time 1.07
# Epoch: 4 | Forget Set Accuracy: 0.597 | Retain Set Accuracy: 0.924 | Test Set Accuracy: 0.866
#
# Epoch: [5][0/36]	Loss -1.4138 (-1.4138)	Accuracy 55.469 (55.469)	Time 0.14
# Epoch: [5][15/36]	Loss -1.6874 (-1.4711)	Accuracy 57.031 (58.887)	Time 1.09
# Epoch: [5][30/36]	Loss -1.8656 (-1.6442)	Accuracy 48.438 (55.544)	Time 1.07
# Epoch: 5 | Forget Set Accuracy: 0.468 | Retain Set Accuracy: 0.919 | Test Set Accuracy: 0.863
#
# Epoch: [6][0/36]	Loss -2.1259 (-2.1259)	Accuracy 47.656 (47.656)	Time 0.12
# Epoch: [6][15/36]	Loss -2.5786 (-2.3000)	Accuracy 37.500 (44.189)	Time 1.03
# Epoch: [6][30/36]	Loss -2.9323 (-2.5750)	Accuracy 32.812 (40.146)	Time 1.07
# Epoch: 6 | Forget Set Accuracy: 0.309 | Retain Set Accuracy: 0.911 | Test Set Accuracy: 0.860
#
# Epoch: [7][0/36]	Loss -3.2815 (-3.2815)	Accuracy 27.344 (27.344)	Time 0.12
# Epoch: [7][15/36]	Loss -4.0141 (-3.5496)	Accuracy 28.125 (29.150)	Time 1.03
# Epoch: [7][30/36]	Loss -4.5002 (-3.8158)	Accuracy 17.969 (26.260)	Time 1.12
# Epoch: 7 | Forget Set Accuracy: 0.190 | Retain Set Accuracy: 0.900 | Test Set Accuracy: 0.851
#
# Epoch: [8][0/36]	Loss -4.4684 (-4.4684)	Accuracy 17.188 (17.188)	Time 0.14
# Epoch: [8][15/36]	Loss -5.1761 (-5.0164)	Accuracy 14.844 (16.895)	Time 1.13
# Epoch: [8][30/36]	Loss -6.3200 (-5.4120)	Accuracy 7.812 (14.516)	Time 1.09
# Epoch: 8 | Forget Set Accuracy: 0.097 | Retain Set Accuracy: 0.887 | Test Set Accuracy: 0.839
#
# Epoch: [9][0/36]	Loss -6.7112 (-6.7112)	Accuracy 6.250 (6.250)	Time 0.12
# Epoch: [9][15/36]	Loss -7.6899 (-6.9090)	Accuracy 3.906 (7.422)	Time 1.00
# Epoch: [9][30/36]	Loss -8.3057 (-7.2971)	Accuracy 2.344 (6.351)	Time 1.10
# Epoch: 9 | Forget Set Accuracy: 0.038 | Retain Set Accuracy: 0.869 | Test Set Accuracy: 0.824
#
# Epoch: [10][0/36]	Loss -9.1311 (-9.1311)	Accuracy 0.781 (0.781)	Time 0.14
# Epoch: [10][15/36]	Loss -10.0173 (-8.9059)	Accuracy 0.781 (3.564)	Time 1.05
# Epoch: [10][30/36]	Loss -11.0630 (-9.4478)	Accuracy 0.000 (2.545)	Time 1.19
# Epoch: 10 | Forget Set Accuracy: 0.012 | Retain Set Accuracy: 0.842 | Test Set Accuracy: 0.802
#
# Epoch: [11][0/36]	Loss -10.5244 (-10.5244)	Accuracy 0.781 (0.781)	Time 0.13
# Epoch: [11][15/36]	Loss -11.4985 (-11.3753)	Accuracy 1.562 (1.172)	Time 1.13
# Epoch: [11][30/36]	Loss -13.2427 (-12.0323)	Accuracy 0.781 (0.781)	Time 1.19
# Epoch: 11 | Forget Set Accuracy: 0.004 | Retain Set Accuracy: 0.805 | Test Set Accuracy: 0.772
#
# Epoch: [12][0/36]	Loss -13.2957 (-13.2957)	Accuracy 0.000 (0.000)	Time 0.11
# Epoch: [12][15/36]	Loss -14.3419 (-14.3226)	Accuracy 0.000 (0.244)	Time 1.00
# Epoch: [12][30/36]	Loss -16.4906 (-14.8640)	Accuracy 0.000 (0.176)	Time 1.10
# Epoch: 12 | Forget Set Accuracy: 0.001 | Retain Set Accuracy: 0.754 | Test Set Accuracy: 0.730
#
# -------------------------    RUN 4
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.91 | Retain Set Accuracy: 0.92
# Epoch: [1][0/36]	Loss -0.2874 (-0.2874)	Accuracy 89.844 (89.844)	Time 0.15
# Epoch: [1][15/36]	Loss -0.4390 (-0.2543)	Accuracy 89.844 (91.943)	Time 1.00
# Epoch: [1][30/36]	Loss -0.2383 (-0.2923)	Accuracy 89.844 (90.499)	Time 1.06
# Epoch: 1 | Forget Set Accuracy: 0.882 | Retain Set Accuracy: 0.927 | Test Set Accuracy: 0.865
#
# Epoch: [2][0/36]	Loss -0.4417 (-0.4417)	Accuracy 86.719 (86.719)	Time 0.32
# Epoch: [2][15/36]	Loss -0.5309 (-0.3901)	Accuracy 78.906 (86.572)	Time 1.08
# Epoch: [2][30/36]	Loss -0.4440 (-0.4287)	Accuracy 83.594 (85.207)	Time 1.02
# Epoch: 2 | Forget Set Accuracy: 0.815 | Retain Set Accuracy: 0.927 | Test Set Accuracy: 0.868
#
# Epoch: [3][0/36]	Loss -0.6843 (-0.6843)	Accuracy 76.562 (76.562)	Time 0.21
# Epoch: [3][15/36]	Loss -0.8582 (-0.6424)	Accuracy 74.219 (79.590)	Time 1.07
# Epoch: [3][30/36]	Loss -0.7343 (-0.7053)	Accuracy 69.531 (77.419)	Time 1.05
# Epoch: 3 | Forget Set Accuracy: 0.722 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.867
#
# Epoch: [4][0/36]	Loss -0.7993 (-0.7993)	Accuracy 73.438 (73.438)	Time 0.49
# Epoch: [4][15/36]	Loss -1.0268 (-0.9662)	Accuracy 67.969 (69.434)	Time 1.07
# Epoch: [4][30/36]	Loss -1.2151 (-1.0593)	Accuracy 62.500 (67.011)	Time 1.10
# Epoch: 4 | Forget Set Accuracy: 0.598 | Retain Set Accuracy: 0.924 | Test Set Accuracy: 0.867
#
# Epoch: [5][0/36]	Loss -1.4584 (-1.4584)	Accuracy 61.719 (61.719)	Time 0.55
# Epoch: [5][15/36]	Loss -1.4830 (-1.5426)	Accuracy 54.688 (57.520)	Time 1.16
# Epoch: [5][30/36]	Loss -1.9934 (-1.6674)	Accuracy 47.656 (54.536)	Time 1.09
# Epoch: 5 | Forget Set Accuracy: 0.467 | Retain Set Accuracy: 0.918 | Test Set Accuracy: 0.864
#
# Epoch: [6][0/36]	Loss -2.1858 (-2.1858)	Accuracy 52.344 (52.344)	Time 0.30
# Epoch: [6][15/36]	Loss -2.7753 (-2.3833)	Accuracy 35.938 (40.576)	Time 1.05
# Epoch: [6][30/36]	Loss -3.2462 (-2.5544)	Accuracy 35.156 (39.491)	Time 1.10
# Epoch: 6 | Forget Set Accuracy: 0.315 | Retain Set Accuracy: 0.911 | Test Set Accuracy: 0.860
#
# Epoch: [7][0/36]	Loss -3.1151 (-3.1151)	Accuracy 36.719 (36.719)	Time 0.50
# Epoch: [7][15/36]	Loss -3.6895 (-3.5392)	Accuracy 30.469 (28.809)	Time 1.25
# Epoch: [7][30/36]	Loss -4.6185 (-3.7819)	Accuracy 18.750 (26.386)	Time 1.25
# Epoch: 7 | Forget Set Accuracy: 0.193 | Retain Set Accuracy: 0.899 | Test Set Accuracy: 0.853
#
# Epoch: [8][0/36]	Loss -4.4297 (-4.4297)	Accuracy 21.094 (21.094)	Time 0.49
# Epoch: [8][15/36]	Loss -5.4909 (-5.0142)	Accuracy 10.938 (16.455)	Time 1.26
# Epoch: [8][30/36]	Loss -6.0304 (-5.3943)	Accuracy 11.719 (14.138)	Time 1.17
# Epoch: 8 | Forget Set Accuracy: 0.092 | Retain Set Accuracy: 0.886 | Test Set Accuracy: 0.841
#
# Epoch: [9][0/36]	Loss -6.6408 (-6.6408)	Accuracy 4.688 (4.688)	Time 0.33
# Epoch: [9][15/36]	Loss -7.3593 (-6.8295)	Accuracy 6.250 (6.885)	Time 1.27
# Epoch: [9][30/36]	Loss -7.7031 (-7.2704)	Accuracy 8.594 (5.973)	Time 1.43
# Epoch: 9 | Forget Set Accuracy: 0.035 | Retain Set Accuracy: 0.870 | Test Set Accuracy: 0.826
#
# Epoch: [10][0/36]	Loss -8.2639 (-8.2639)	Accuracy 4.688 (4.688)	Time 0.51
# Epoch: [10][15/36]	Loss -9.6753 (-9.0217)	Accuracy 0.781 (2.979)	Time 1.51
# Epoch: [10][30/36]	Loss -10.4567 (-9.4816)	Accuracy 3.125 (2.344)	Time 1.21
# Epoch: 10 | Forget Set Accuracy: 0.012 | Retain Set Accuracy: 0.845 | Test Set Accuracy: 0.805
#
# Epoch: [11][0/36]	Loss -10.7869 (-10.7869)	Accuracy 0.781 (0.781)	Time 0.45
# Epoch: [11][15/36]	Loss -12.3313 (-11.4736)	Accuracy 0.781 (0.830)	Time 1.40
# Epoch: [11][30/36]	Loss -12.9340 (-11.8906)	Accuracy 1.562 (0.731)	Time 1.18
# Epoch: 11 | Forget Set Accuracy: 0.002 | Retain Set Accuracy: 0.813 | Test Set Accuracy: 0.778
#
# Epoch: [12][0/36]	Loss -13.1722 (-13.1722)	Accuracy 0.000 (0.000)	Time 0.40
# Epoch: [12][15/36]	Loss -14.6143 (-14.1431)	Accuracy 0.781 (0.195)	Time 1.35
# Epoch: [12][30/36]	Loss -15.7861 (-14.6933)	Accuracy 0.000 (0.176)	Time 1.13
# Epoch: 12 | Forget Set Accuracy: 0.001 | Retain Set Accuracy: 0.763 | Test Set Accuracy: 0.741
#
# -------------------------    RUN 5
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.92 | Retain Set Accuracy: 0.92
# Epoch: [1][0/36]	Loss -0.1647 (-0.1647)	Accuracy 94.531 (94.531)	Time 0.14
# Epoch: [1][15/36]	Loss -0.3347 (-0.2590)	Accuracy 87.500 (90.967)	Time 1.07
# Epoch: [1][30/36]	Loss -0.3956 (-0.2889)	Accuracy 86.719 (90.247)	Time 1.03
# Epoch: 1 | Forget Set Accuracy: 0.872 | Retain Set Accuracy: 0.928 | Test Set Accuracy: 0.866
#
# Epoch: [2][0/36]	Loss -0.3464 (-0.3464)	Accuracy 91.406 (91.406)	Time 0.33
# Epoch: [2][15/36]	Loss -0.4618 (-0.4094)	Accuracy 84.375 (86.426)	Time 1.11
# Epoch: [2][30/36]	Loss -0.4418 (-0.4314)	Accuracy 87.500 (85.711)	Time 1.18
# Epoch: 2 | Forget Set Accuracy: 0.820 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.867
#
# Epoch: [3][0/36]	Loss -0.5537 (-0.5537)	Accuracy 82.031 (82.031)	Time 0.19
# Epoch: [3][15/36]	Loss -0.7008 (-0.6138)	Accuracy 77.344 (79.980)	Time 1.51
# Epoch: [3][30/36]	Loss -0.9115 (-0.6698)	Accuracy 70.312 (78.075)	Time 1.13
# Epoch: 3 | Forget Set Accuracy: 0.727 | Retain Set Accuracy: 0.927 | Test Set Accuracy: 0.867
#
# Epoch: [4][0/36]	Loss -0.8660 (-0.8660)	Accuracy 71.875 (71.875)	Time 0.19
# Epoch: [4][15/36]	Loss -1.0111 (-0.9986)	Accuracy 67.969 (68.896)	Time 1.11
# Epoch: [4][30/36]	Loss -1.3050 (-1.0846)	Accuracy 62.500 (66.482)	Time 1.12
# Epoch: 4 | Forget Set Accuracy: 0.597 | Retain Set Accuracy: 0.922 | Test Set Accuracy: 0.867
#
# Epoch: [5][0/36]	Loss -1.6108 (-1.6108)	Accuracy 54.688 (54.688)	Time 0.35
# Epoch: [5][15/36]	Loss -1.4400 (-1.5086)	Accuracy 56.250 (57.275)	Time 1.09
# Epoch: [5][30/36]	Loss -1.8439 (-1.6616)	Accuracy 50.000 (54.360)	Time 1.03
# Epoch: 5 | Forget Set Accuracy: 0.452 | Retain Set Accuracy: 0.920 | Test Set Accuracy: 0.864
#
# Epoch: [6][0/36]	Loss -2.0966 (-2.0966)	Accuracy 47.656 (47.656)	Time 0.22
# Epoch: [6][15/36]	Loss -2.6349 (-2.2704)	Accuracy 36.719 (43.799)	Time 1.20
# Epoch: [6][30/36]	Loss -2.9772 (-2.5593)	Accuracy 32.031 (39.844)	Time 1.19
# Epoch: 6 | Forget Set Accuracy: 0.317 | Retain Set Accuracy: 0.912 | Test Set Accuracy: 0.860
#
# Epoch: [7][0/36]	Loss -3.5877 (-3.5877)	Accuracy 24.219 (24.219)	Time 0.21
# Epoch: [7][15/36]	Loss -4.0866 (-3.5617)	Accuracy 25.781 (27.881)	Time 1.05
# Epoch: [7][30/36]	Loss -4.8593 (-3.8900)	Accuracy 15.625 (24.597)	Time 1.13
# Epoch: 7 | Forget Set Accuracy: 0.185 | Retain Set Accuracy: 0.902 | Test Set Accuracy: 0.854
#
# Epoch: [8][0/36]	Loss -5.0671 (-5.0671)	Accuracy 19.531 (19.531)	Time 0.32
# Epoch: [8][15/36]	Loss -5.2193 (-4.9919)	Accuracy 19.531 (17.090)	Time 1.18
# Epoch: [8][30/36]	Loss -6.2688 (-5.3603)	Accuracy 6.250 (14.567)	Time 1.00
# Epoch: 8 | Forget Set Accuracy: 0.094 | Retain Set Accuracy: 0.892 | Test Set Accuracy: 0.842
#
# Epoch: [9][0/36]	Loss -6.8552 (-6.8552)	Accuracy 7.812 (7.812)	Time 0.15
# Epoch: [9][15/36]	Loss -7.5024 (-6.8489)	Accuracy 6.250 (8.105)	Time 1.01
# Epoch: [9][30/36]	Loss -7.7867 (-7.2310)	Accuracy 3.125 (6.804)	Time 1.04
# Epoch: 9 | Forget Set Accuracy: 0.040 | Retain Set Accuracy: 0.871 | Test Set Accuracy: 0.828
#
# Epoch: [10][0/36]	Loss -8.0942 (-8.0942)	Accuracy 3.125 (3.125)	Time 0.45
# Epoch: [10][15/36]	Loss -9.4482 (-8.8678)	Accuracy 0.781 (3.223)	Time 1.21
# Epoch: [10][30/36]	Loss -9.6005 (-9.3155)	Accuracy 0.000 (2.646)	Time 1.14
# Epoch: 10 | Forget Set Accuracy: 0.014 | Retain Set Accuracy: 0.846 | Test Set Accuracy: 0.808
#
# Epoch: [11][0/36]	Loss -10.5127 (-10.5127)	Accuracy 1.562 (1.562)	Time 0.39
# Epoch: [11][15/36]	Loss -11.9475 (-11.1384)	Accuracy 0.781 (0.586)	Time 1.18
# Epoch: [11][30/36]	Loss -12.4258 (-11.6856)	Accuracy 0.781 (0.630)	Time 1.15
# Epoch: 11 | Forget Set Accuracy: 0.003 | Retain Set Accuracy: 0.813 | Test Set Accuracy: 0.782
#
# Epoch: [12][0/36]	Loss -13.8231 (-13.8231)	Accuracy 0.000 (0.000)	Time 0.39
# Epoch: [12][15/36]	Loss -14.6732 (-13.7152)	Accuracy 0.000 (0.293)	Time 1.15
# Epoch: [12][30/36]	Loss -15.4143 (-14.3278)	Accuracy 0.000 (0.151)	Time 1.02
# Epoch: 12 | Forget Set Accuracy: 0.000 | Retain Set Accuracy: 0.767 | Test Set Accuracy: 0.744
#
# -------------------------    RUN 6
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.92 | Retain Set Accuracy: 0.93
# Epoch: [1][0/36]	Loss -0.3496 (-0.3496)	Accuracy 90.625 (90.625)	Time 0.20
# Epoch: [1][15/36]	Loss -0.3656 (-0.2750)	Accuracy 87.500 (91.016)	Time 1.18
# Epoch: [1][30/36]	Loss -0.3225 (-0.2992)	Accuracy 89.062 (90.549)	Time 1.16
# Epoch: 1 | Forget Set Accuracy: 0.881 | Retain Set Accuracy: 0.925 | Test Set Accuracy: 0.865
#
# Epoch: [2][0/36]	Loss -0.4910 (-0.4910)	Accuracy 82.031 (82.031)	Time 0.37
# Epoch: [2][15/36]	Loss -0.4722 (-0.4051)	Accuracy 83.594 (86.426)	Time 1.13
# Epoch: [2][30/36]	Loss -0.3996 (-0.4466)	Accuracy 85.156 (85.131)	Time 1.29
# Epoch: 2 | Forget Set Accuracy: 0.814 | Retain Set Accuracy: 0.927 | Test Set Accuracy: 0.867
#
# Epoch: [3][0/36]	Loss -0.5399 (-0.5399)	Accuracy 84.375 (84.375)	Time 0.44
# Epoch: [3][15/36]	Loss -0.7667 (-0.6281)	Accuracy 78.125 (80.713)	Time 1.09
# Epoch: [3][30/36]	Loss -0.6506 (-0.6974)	Accuracy 80.469 (78.100)	Time 1.08
# Epoch: 3 | Forget Set Accuracy: 0.720 | Retain Set Accuracy: 0.928 | Test Set Accuracy: 0.867
#
# Epoch: [4][0/36]	Loss -0.7102 (-0.7102)	Accuracy 73.438 (73.438)	Time 0.53
# Epoch: [4][15/36]	Loss -1.0968 (-0.9598)	Accuracy 64.062 (70.557)	Time 1.21
# Epoch: [4][30/36]	Loss -1.1305 (-1.0179)	Accuracy 64.062 (68.775)	Time 1.22
# Epoch: 4 | Forget Set Accuracy: 0.609 | Retain Set Accuracy: 0.923 | Test Set Accuracy: 0.866
#
# Epoch: [5][0/36]	Loss -1.3217 (-1.3217)	Accuracy 57.812 (57.812)	Time 0.46
# Epoch: [5][15/36]	Loss -1.3442 (-1.5007)	Accuracy 60.156 (56.787)	Time 1.27
# Epoch: [5][30/36]	Loss -1.7459 (-1.6560)	Accuracy 54.688 (53.604)	Time 1.24
# Epoch: 5 | Forget Set Accuracy: 0.461 | Retain Set Accuracy: 0.920 | Test Set Accuracy: 0.864
#
# Epoch: [6][0/36]	Loss -2.4756 (-2.4756)	Accuracy 47.656 (47.656)	Time 0.34
# Epoch: [6][15/36]	Loss -2.6029 (-2.2987)	Accuracy 42.969 (43.652)	Time 1.26
# Epoch: [6][30/36]	Loss -2.8911 (-2.5133)	Accuracy 35.938 (40.373)	Time 1.13
# Epoch: 6 | Forget Set Accuracy: 0.308 | Retain Set Accuracy: 0.912 | Test Set Accuracy: 0.861
#
# Epoch: [7][0/36]	Loss -2.9052 (-2.9052)	Accuracy 33.594 (33.594)	Time 0.40
# Epoch: [7][15/36]	Loss -4.0314 (-3.4562)	Accuracy 23.438 (28.955)	Time 1.28
# Epoch: [7][30/36]	Loss -4.5961 (-3.7550)	Accuracy 22.656 (26.033)	Time 1.02
# Epoch: 7 | Forget Set Accuracy: 0.189 | Retain Set Accuracy: 0.902 | Test Set Accuracy: 0.853
#
# Epoch: [8][0/36]	Loss -4.4177 (-4.4177)	Accuracy 21.875 (21.875)	Time 0.43
# Epoch: [8][15/36]	Loss -5.1170 (-5.0394)	Accuracy 18.750 (17.432)	Time 1.37
# Epoch: [8][30/36]	Loss -6.2038 (-5.4086)	Accuracy 10.938 (14.819)	Time 1.28
# Epoch: 8 | Forget Set Accuracy: 0.093 | Retain Set Accuracy: 0.890 | Test Set Accuracy: 0.841
#
# Epoch: [9][0/36]	Loss -6.4260 (-6.4260)	Accuracy 5.469 (5.469)	Time 0.41
# Epoch: [9][15/36]	Loss -7.5133 (-6.9646)	Accuracy 3.906 (7.080)	Time 1.02
# Epoch: [9][30/36]	Loss -7.7590 (-7.3394)	Accuracy 3.125 (6.351)	Time 1.06
# Epoch: 9 | Forget Set Accuracy: 0.042 | Retain Set Accuracy: 0.870 | Test Set Accuracy: 0.825
#
# Epoch: [10][0/36]	Loss -8.6098 (-8.6098)	Accuracy 6.250 (6.250)	Time 0.50
# Epoch: [10][15/36]	Loss -9.0441 (-8.8726)	Accuracy 0.781 (2.979)	Time 1.15
# Epoch: [10][30/36]	Loss -10.0797 (-9.3612)	Accuracy 3.125 (2.571)	Time 1.07
# Epoch: 10 | Forget Set Accuracy: 0.010 | Retain Set Accuracy: 0.846 | Test Set Accuracy: 0.805
#
# Epoch: [11][0/36]	Loss -11.0030 (-11.0030)	Accuracy 0.781 (0.781)	Time 0.42
# Epoch: [11][15/36]	Loss -11.8541 (-11.3745)	Accuracy 0.000 (0.684)	Time 1.22
# Epoch: [11][30/36]	Loss -13.0970 (-11.9290)	Accuracy 1.562 (0.605)	Time 1.22
# Epoch: 11 | Forget Set Accuracy: 0.003 | Retain Set Accuracy: 0.813 | Test Set Accuracy: 0.778
#
# Epoch: [12][0/36]	Loss -13.3350 (-13.3350)	Accuracy 0.000 (0.000)	Time 0.37
# Epoch: [12][15/36]	Loss -15.1392 (-13.8900)	Accuracy 0.000 (0.146)	Time 1.19
# Epoch: [12][30/36]	Loss -15.7313 (-14.5714)	Accuracy 0.000 (0.151)	Time 1.19
# Epoch: 12 | Forget Set Accuracy: 0.000 | Retain Set Accuracy: 0.768 | Test Set Accuracy: 0.741
#
# -------------------------    RUN 7
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.92 | Retain Set Accuracy: 0.92
# Epoch: [1][0/36]	Loss -0.1524 (-0.1524)	Accuracy 93.750 (93.750)	Time 0.12
# Epoch: [1][15/36]	Loss -0.3614 (-0.2828)	Accuracy 89.062 (90.479)	Time 1.27
# Epoch: [1][30/36]	Loss -0.2872 (-0.3033)	Accuracy 90.625 (90.071)	Time 1.15
# Epoch: 1 | Forget Set Accuracy: 0.881 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.865
#
# Epoch: [2][0/36]	Loss -0.2884 (-0.2884)	Accuracy 87.500 (87.500)	Time 0.26
# Epoch: [2][15/36]	Loss -0.5199 (-0.4358)	Accuracy 88.281 (85.547)	Time 1.24
# Epoch: [2][30/36]	Loss -0.5729 (-0.4377)	Accuracy 79.688 (85.534)	Time 1.25
# Epoch: 2 | Forget Set Accuracy: 0.825 | Retain Set Accuracy: 0.928 | Test Set Accuracy: 0.867
#
# Epoch: [3][0/36]	Loss -0.6158 (-0.6158)	Accuracy 82.031 (82.031)	Time 0.37
# Epoch: [3][15/36]	Loss -0.7001 (-0.6177)	Accuracy 77.344 (80.664)	Time 1.14
# Epoch: [3][30/36]	Loss -1.1321 (-0.6821)	Accuracy 66.406 (78.201)	Time 1.06
# Epoch: 3 | Forget Set Accuracy: 0.720 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.867
#
# Epoch: [4][0/36]	Loss -0.9118 (-0.9118)	Accuracy 71.875 (71.875)	Time 0.29
# Epoch: [4][15/36]	Loss -1.2057 (-0.9317)	Accuracy 64.844 (70.459)	Time 1.15
# Epoch: [4][30/36]	Loss -1.6382 (-1.0501)	Accuracy 57.031 (67.868)	Time 1.43
# Epoch: 4 | Forget Set Accuracy: 0.603 | Retain Set Accuracy: 0.924 | Test Set Accuracy: 0.866
#
# Epoch: [5][0/36]	Loss -1.1836 (-1.1836)	Accuracy 62.500 (62.500)	Time 0.35
# Epoch: [5][15/36]	Loss -1.8923 (-1.5115)	Accuracy 50.000 (57.031)	Time 1.12
# Epoch: [5][30/36]	Loss -1.9506 (-1.6598)	Accuracy 46.094 (53.856)	Time 1.08
# Epoch: 5 | Forget Set Accuracy: 0.459 | Retain Set Accuracy: 0.921 | Test Set Accuracy: 0.864
#
# Epoch: [6][0/36]	Loss -1.9013 (-1.9013)	Accuracy 45.312 (45.312)	Time 0.26
# Epoch: [6][15/36]	Loss -2.3831 (-2.3383)	Accuracy 43.750 (42.188)	Time 1.53
# Epoch: [6][30/36]	Loss -2.7501 (-2.5109)	Accuracy 42.188 (39.819)	Time 1.09
# Epoch: 6 | Forget Set Accuracy: 0.314 | Retain Set Accuracy: 0.909 | Test Set Accuracy: 0.860
#
# Epoch: [7][0/36]	Loss -3.4283 (-3.4283)	Accuracy 25.781 (25.781)	Time 0.17
# Epoch: [7][15/36]	Loss -3.6518 (-3.4898)	Accuracy 30.469 (28.027)	Time 1.19
# Epoch: [7][30/36]	Loss -4.7244 (-3.8114)	Accuracy 21.094 (25.706)	Time 1.11
# Epoch: 7 | Forget Set Accuracy: 0.187 | Retain Set Accuracy: 0.903 | Test Set Accuracy: 0.852
#
# Epoch: [8][0/36]	Loss -4.1981 (-4.1981)	Accuracy 20.312 (20.312)	Time 0.40
# Epoch: [8][15/36]	Loss -5.6050 (-5.0006)	Accuracy 14.062 (16.846)	Time 1.12
# Epoch: [8][30/36]	Loss -6.5782 (-5.4156)	Accuracy 7.812 (14.642)	Time 1.25
# Epoch: 8 | Forget Set Accuracy: 0.097 | Retain Set Accuracy: 0.886 | Test Set Accuracy: 0.841
#
# Epoch: [9][0/36]	Loss -6.4961 (-6.4961)	Accuracy 9.375 (9.375)	Time 0.36
# Epoch: [9][15/36]	Loss -6.9800 (-6.8963)	Accuracy 5.469 (6.641)	Time 1.05
# Epoch: [9][30/36]	Loss -8.1114 (-7.2203)	Accuracy 1.562 (6.401)	Time 1.04
# Epoch: 9 | Forget Set Accuracy: 0.035 | Retain Set Accuracy: 0.870 | Test Set Accuracy: 0.826
#
# Epoch: [10][0/36]	Loss -8.7084 (-8.7084)	Accuracy 3.125 (3.125)	Time 0.30
# Epoch: [10][15/36]	Loss -9.4642 (-9.0383)	Accuracy 2.344 (3.076)	Time 1.14
# Epoch: [10][30/36]	Loss -10.4102 (-9.4741)	Accuracy 3.125 (2.344)	Time 1.07
# Epoch: 10 | Forget Set Accuracy: 0.012 | Retain Set Accuracy: 0.845 | Test Set Accuracy: 0.807
#
# Epoch: [11][0/36]	Loss -10.4495 (-10.4495)	Accuracy 0.000 (0.000)	Time 0.39
# Epoch: [11][15/36]	Loss -11.0859 (-11.3956)	Accuracy 0.000 (0.830)	Time 1.08
# Epoch: [11][30/36]	Loss -12.4445 (-11.8967)	Accuracy 0.000 (0.655)	Time 0.98
# Epoch: 11 | Forget Set Accuracy: 0.002 | Retain Set Accuracy: 0.815 | Test Set Accuracy: 0.780
#
# Epoch: [12][0/36]	Loss -14.0919 (-14.0919)	Accuracy 0.000 (0.000)	Time 0.35
# Epoch: [12][15/36]	Loss -14.1601 (-13.9398)	Accuracy 0.781 (0.244)	Time 1.12
# Epoch: [12][30/36]	Loss -15.6164 (-14.6278)	Accuracy 0.000 (0.252)	Time 1.04
# Epoch: 12 | Forget Set Accuracy: 0.001 | Retain Set Accuracy: 0.772 | Test Set Accuracy: 0.744
#
# -------------------------    RUN 8
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.92 | Retain Set Accuracy: 0.92
# Epoch: [1][0/36]	Loss -0.2568 (-0.2568)	Accuracy 90.625 (90.625)	Time 0.11
# Epoch: [1][15/36]	Loss -0.2634 (-0.2792)	Accuracy 92.188 (90.723)	Time 0.98
# Epoch: [1][30/36]	Loss -0.1809 (-0.2780)	Accuracy 93.750 (91.053)	Time 1.03
# Epoch: 1 | Forget Set Accuracy: 0.871 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.865
#
# Epoch: [2][0/36]	Loss -0.3270 (-0.3270)	Accuracy 90.625 (90.625)	Time 0.33
# Epoch: [2][15/36]	Loss -0.4071 (-0.4048)	Accuracy 85.938 (86.621)	Time 1.27
# Epoch: [2][30/36]	Loss -0.5480 (-0.4203)	Accuracy 82.031 (86.013)	Time 1.08
# Epoch: 2 | Forget Set Accuracy: 0.814 | Retain Set Accuracy: 0.928 | Test Set Accuracy: 0.868
#
# Epoch: [3][0/36]	Loss -0.5231 (-0.5231)	Accuracy 82.812 (82.812)	Time 0.17
# Epoch: [3][15/36]	Loss -0.7580 (-0.5638)	Accuracy 75.781 (80.811)	Time 1.04
# Epoch: [3][30/36]	Loss -0.9656 (-0.6471)	Accuracy 74.219 (78.150)	Time 1.00
# Epoch: 3 | Forget Set Accuracy: 0.726 | Retain Set Accuracy: 0.924 | Test Set Accuracy: 0.867
#
# Epoch: [4][0/36]	Loss -0.7844 (-0.7844)	Accuracy 78.125 (78.125)	Time 0.21
# Epoch: [4][15/36]	Loss -1.0776 (-0.9442)	Accuracy 68.750 (70.264)	Time 1.07
# Epoch: [4][30/36]	Loss -1.3643 (-1.0538)	Accuracy 58.594 (68.221)	Time 1.09
# Epoch: 4 | Forget Set Accuracy: 0.610 | Retain Set Accuracy: 0.923 | Test Set Accuracy: 0.866
#
# Epoch: [5][0/36]	Loss -1.3808 (-1.3808)	Accuracy 60.156 (60.156)	Time 0.45
# Epoch: [5][15/36]	Loss -1.4306 (-1.5340)	Accuracy 55.469 (56.738)	Time 1.04
# Epoch: [5][30/36]	Loss -1.9678 (-1.6883)	Accuracy 52.344 (53.453)	Time 1.05
# Epoch: 5 | Forget Set Accuracy: 0.453 | Retain Set Accuracy: 0.919 | Test Set Accuracy: 0.863
#
# Epoch: [6][0/36]	Loss -2.0398 (-2.0398)	Accuracy 48.438 (48.438)	Time 0.47
# Epoch: [6][15/36]	Loss -2.4807 (-2.2922)	Accuracy 42.969 (42.529)	Time 1.04
# Epoch: [6][30/36]	Loss -2.6881 (-2.5418)	Accuracy 39.844 (39.541)	Time 1.10
# Epoch: 6 | Forget Set Accuracy: 0.313 | Retain Set Accuracy: 0.911 | Test Set Accuracy: 0.860
#
# Epoch: [7][0/36]	Loss -3.3517 (-3.3517)	Accuracy 29.688 (29.688)	Time 0.22
# Epoch: [7][15/36]	Loss -3.9269 (-3.4496)	Accuracy 25.781 (28.955)	Time 1.26
# Epoch: [7][30/36]	Loss -4.2057 (-3.7954)	Accuracy 21.094 (25.781)	Time 1.14
# Epoch: 7 | Forget Set Accuracy: 0.184 | Retain Set Accuracy: 0.904 | Test Set Accuracy: 0.853
#
# Epoch: [8][0/36]	Loss -4.3914 (-4.3914)	Accuracy 22.656 (22.656)	Time 0.14
# Epoch: [8][15/36]	Loss -5.4736 (-5.0331)	Accuracy 12.500 (16.357)	Time 1.08
# Epoch: [8][30/36]	Loss -5.8621 (-5.3575)	Accuracy 9.375 (14.592)	Time 1.05
# Epoch: 8 | Forget Set Accuracy: 0.096 | Retain Set Accuracy: 0.888 | Test Set Accuracy: 0.841
#
# Epoch: [9][0/36]	Loss -6.2385 (-6.2385)	Accuracy 14.844 (14.844)	Time 0.25
# Epoch: [9][15/36]	Loss -6.4153 (-6.7651)	Accuracy 12.500 (8.594)	Time 1.28
# Epoch: [9][30/36]	Loss -7.9448 (-7.2455)	Accuracy 3.125 (6.880)	Time 1.14
# Epoch: 9 | Forget Set Accuracy: 0.041 | Retain Set Accuracy: 0.868 | Test Set Accuracy: 0.827
#
# Epoch: [10][0/36]	Loss -8.7943 (-8.7943)	Accuracy 2.344 (2.344)	Time 0.47
# Epoch: [10][15/36]	Loss -9.7951 (-9.1286)	Accuracy 1.562 (3.125)	Time 1.24
# Epoch: [10][30/36]	Loss -10.5630 (-9.4830)	Accuracy 2.344 (2.772)	Time 1.15
# Epoch: 10 | Forget Set Accuracy: 0.014 | Retain Set Accuracy: 0.844 | Test Set Accuracy: 0.805
#
# Epoch: [11][0/36]	Loss -10.6281 (-10.6281)	Accuracy 0.000 (0.000)	Time 0.33
# Epoch: [11][15/36]	Loss -12.1547 (-11.4498)	Accuracy 0.000 (0.684)	Time 1.25
# Epoch: [11][30/36]	Loss -12.7326 (-11.8365)	Accuracy 1.562 (0.630)	Time 1.16
# Epoch: 11 | Forget Set Accuracy: 0.002 | Retain Set Accuracy: 0.808 | Test Set Accuracy: 0.777
#
# Epoch: [12][0/36]	Loss -13.6536 (-13.6536)	Accuracy 0.000 (0.000)	Time 0.19
# Epoch: [12][15/36]	Loss -14.5758 (-13.8309)	Accuracy 0.781 (0.244)	Time 1.19
# Epoch: [12][30/36]	Loss -15.3291 (-14.5519)	Accuracy 0.000 (0.252)	Time 1.15
# Epoch: 12 | Forget Set Accuracy: 0.000 | Retain Set Accuracy: 0.762 | Test Set Accuracy: 0.739
#
# -------------------------    RUN 9
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.92 | Retain Set Accuracy: 0.92
# Epoch: [1][0/36]	Loss -0.2126 (-0.2126)	Accuracy 93.750 (93.750)	Time 0.08
# Epoch: [1][15/36]	Loss -0.2588 (-0.2913)	Accuracy 92.969 (91.211)	Time 1.12
# Epoch: [1][30/36]	Loss -0.2579 (-0.3016)	Accuracy 89.844 (90.297)	Time 1.14
# Epoch: 1 | Forget Set Accuracy: 0.884 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.866
#
# Epoch: [2][0/36]	Loss -0.3146 (-0.3146)	Accuracy 89.844 (89.844)	Time 0.44
# Epoch: [2][15/36]	Loss -0.4663 (-0.3872)	Accuracy 82.812 (86.621)	Time 1.21
# Epoch: [2][30/36]	Loss -0.5762 (-0.4417)	Accuracy 79.688 (85.484)	Time 1.20
# Epoch: 2 | Forget Set Accuracy: 0.817 | Retain Set Accuracy: 0.927 | Test Set Accuracy: 0.867
#
# Epoch: [3][0/36]	Loss -0.4387 (-0.4387)	Accuracy 84.375 (84.375)	Time 0.37
# Epoch: [3][15/36]	Loss -0.6202 (-0.5664)	Accuracy 78.125 (80.420)	Time 1.00
# Epoch: [3][30/36]	Loss -0.6301 (-0.6645)	Accuracy 79.688 (77.873)	Time 0.86
# Epoch: 3 | Forget Set Accuracy: 0.732 | Retain Set Accuracy: 0.923 | Test Set Accuracy: 0.867
#
# Epoch: [4][0/36]	Loss -0.9656 (-0.9656)	Accuracy 72.656 (72.656)	Time 0.34
# Epoch: [4][15/36]	Loss -0.9001 (-0.9911)	Accuracy 71.094 (69.629)	Time 0.93
# Epoch: [4][30/36]	Loss -1.3443 (-1.1093)	Accuracy 60.156 (66.179)	Time 0.91
# Epoch: 4 | Forget Set Accuracy: 0.592 | Retain Set Accuracy: 0.923 | Test Set Accuracy: 0.866
#
# Epoch: [5][0/36]	Loss -1.4945 (-1.4945)	Accuracy 59.375 (59.375)	Time 0.25
# Epoch: [5][15/36]	Loss -1.8849 (-1.5607)	Accuracy 52.344 (55.615)	Time 0.92
# Epoch: [5][30/36]	Loss -2.0274 (-1.6847)	Accuracy 47.656 (53.957)	Time 0.86
# Epoch: 5 | Forget Set Accuracy: 0.453 | Retain Set Accuracy: 0.919 | Test Set Accuracy: 0.864
#
# Epoch: [6][0/36]	Loss -2.1040 (-2.1040)	Accuracy 50.000 (50.000)	Time 0.40
# Epoch: [6][15/36]	Loss -2.3102 (-2.3405)	Accuracy 40.625 (43.213)	Time 0.89
# Epoch: [6][30/36]	Loss -2.6362 (-2.5744)	Accuracy 33.594 (39.516)	Time 0.88
# Epoch: 6 | Forget Set Accuracy: 0.310 | Retain Set Accuracy: 0.911 | Test Set Accuracy: 0.860
#
# Epoch: [7][0/36]	Loss -3.3348 (-3.3348)	Accuracy 31.250 (31.250)	Time 0.37
# Epoch: [7][15/36]	Loss -3.4884 (-3.5158)	Accuracy 32.812 (28.223)	Time 0.95
# Epoch: [7][30/36]	Loss -4.3066 (-3.8226)	Accuracy 21.094 (25.202)	Time 0.86
# Epoch: 7 | Forget Set Accuracy: 0.191 | Retain Set Accuracy: 0.901 | Test Set Accuracy: 0.852
#
# Epoch: [8][0/36]	Loss -4.5770 (-4.5770)	Accuracy 21.875 (21.875)	Time 0.25
# Epoch: [8][15/36]	Loss -5.3064 (-4.9937)	Accuracy 16.406 (17.334)	Time 0.91
# Epoch: [8][30/36]	Loss -5.6866 (-5.3360)	Accuracy 8.594 (14.693)	Time 0.88
# Epoch: 8 | Forget Set Accuracy: 0.096 | Retain Set Accuracy: 0.888 | Test Set Accuracy: 0.841
#
# Epoch: [9][0/36]	Loss -6.6093 (-6.6093)	Accuracy 11.719 (11.719)	Time 0.30
# Epoch: [9][15/36]	Loss -7.6487 (-6.9626)	Accuracy 2.344 (7.324)	Time 0.96
# Epoch: [9][30/36]	Loss -8.3245 (-7.3324)	Accuracy 3.125 (6.653)	Time 0.90
# Epoch: 9 | Forget Set Accuracy: 0.035 | Retain Set Accuracy: 0.867 | Test Set Accuracy: 0.824
#
# Epoch: [10][0/36]	Loss -8.3399 (-8.3399)	Accuracy 4.688 (4.688)	Time 0.33
# Epoch: [10][15/36]	Loss -9.9991 (-9.0441)	Accuracy 2.344 (2.832)	Time 0.99
# Epoch: [10][30/36]	Loss -10.5367 (-9.6028)	Accuracy 2.344 (2.344)	Time 0.95
# Epoch: 10 | Forget Set Accuracy: 0.010 | Retain Set Accuracy: 0.840 | Test Set Accuracy: 0.803
#
# Epoch: [11][0/36]	Loss -10.8676 (-10.8676)	Accuracy 2.344 (2.344)	Time 0.19
# Epoch: [11][15/36]	Loss -11.9510 (-11.4238)	Accuracy 0.781 (0.977)	Time 0.96
# Epoch: [11][30/36]	Loss -13.2877 (-11.9688)	Accuracy 0.000 (0.630)	Time 0.96
# Epoch: 11 | Forget Set Accuracy: 0.003 | Retain Set Accuracy: 0.806 | Test Set Accuracy: 0.774
#
# Epoch: [12][0/36]	Loss -13.4791 (-13.4791)	Accuracy 0.781 (0.781)	Time 0.45
# Epoch: [12][15/36]	Loss -14.8738 (-14.0841)	Accuracy 0.000 (0.293)	Time 1.01
# Epoch: [12][30/36]	Loss -16.6037 (-14.7362)	Accuracy 0.000 (0.202)	Time 0.93
# Epoch: 12 | Forget Set Accuracy: 0.000 | Retain Set Accuracy: 0.758 | Test Set Accuracy: 0.736
#
# -------------------------    RUN 10
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.92 | Retain Set Accuracy: 0.93
# Epoch: [1][0/36]	Loss -0.3008 (-0.3008)	Accuracy 90.625 (90.625)	Time 0.12
# Epoch: [1][15/36]	Loss -0.2316 (-0.2429)	Accuracy 93.750 (91.650)	Time 0.92
# Epoch: [1][30/36]	Loss -0.3874 (-0.2814)	Accuracy 89.062 (90.776)	Time 0.88
# Epoch: 1 | Forget Set Accuracy: 0.877 | Retain Set Accuracy: 0.927 | Test Set Accuracy: 0.865
#
# Epoch: [2][0/36]	Loss -0.4763 (-0.4763)	Accuracy 85.156 (85.156)	Time 0.38
# Epoch: [2][15/36]	Loss -0.3134 (-0.3875)	Accuracy 88.281 (86.670)	Time 0.95
# Epoch: [2][30/36]	Loss -0.6228 (-0.4481)	Accuracy 75.000 (85.307)	Time 0.93
# Epoch: 2 | Forget Set Accuracy: 0.821 | Retain Set Accuracy: 0.927 | Test Set Accuracy: 0.868
#
# Epoch: [3][0/36]	Loss -0.6782 (-0.6782)	Accuracy 80.469 (80.469)	Time 0.15
# Epoch: [3][15/36]	Loss -0.6297 (-0.6395)	Accuracy 77.344 (79.834)	Time 0.93
# Epoch: [3][30/36]	Loss -0.6930 (-0.6742)	Accuracy 75.000 (77.747)	Time 0.91
# Epoch: 3 | Forget Set Accuracy: 0.721 | Retain Set Accuracy: 0.925 | Test Set Accuracy: 0.867
#
# Epoch: [4][0/36]	Loss -0.8534 (-0.8534)	Accuracy 71.875 (71.875)	Time 0.26
# Epoch: [4][15/36]	Loss -1.1474 (-0.9853)	Accuracy 67.188 (70.361)	Time 0.95
# Epoch: [4][30/36]	Loss -1.6176 (-1.0670)	Accuracy 59.375 (67.969)	Time 0.97
# Epoch: 4 | Forget Set Accuracy: 0.593 | Retain Set Accuracy: 0.924 | Test Set Accuracy: 0.866
#
# Epoch: [5][0/36]	Loss -1.5617 (-1.5617)	Accuracy 56.250 (56.250)	Time 0.32
# Epoch: [5][15/36]	Loss -1.7080 (-1.5424)	Accuracy 55.469 (56.592)	Time 0.88
# Epoch: [5][30/36]	Loss -2.3100 (-1.6882)	Accuracy 47.656 (54.234)	Time 0.88
# Epoch: 5 | Forget Set Accuracy: 0.456 | Retain Set Accuracy: 0.918 | Test Set Accuracy: 0.863
#
# Epoch: [6][0/36]	Loss -2.0408 (-2.0408)	Accuracy 43.750 (43.750)	Time 0.22
# Epoch: [6][15/36]	Loss -2.9789 (-2.4390)	Accuracy 33.594 (41.846)	Time 0.88
# Epoch: [6][30/36]	Loss -2.7410 (-2.5778)	Accuracy 36.719 (39.214)	Time 0.84
# Epoch: 6 | Forget Set Accuracy: 0.314 | Retain Set Accuracy: 0.912 | Test Set Accuracy: 0.860
#
# Epoch: [7][0/36]	Loss -3.2149 (-3.2149)	Accuracy 28.125 (28.125)	Time 0.10
# Epoch: [7][15/36]	Loss -3.8928 (-3.4267)	Accuracy 25.781 (30.127)	Time 0.84
# Epoch: [7][30/36]	Loss -4.1499 (-3.8126)	Accuracy 17.969 (25.781)	Time 0.86
# Epoch: 7 | Forget Set Accuracy: 0.182 | Retain Set Accuracy: 0.903 | Test Set Accuracy: 0.853
#
# Epoch: [8][0/36]	Loss -4.3546 (-4.3546)	Accuracy 17.969 (17.969)	Time 0.33
# Epoch: [8][15/36]	Loss -5.1695 (-5.0444)	Accuracy 13.281 (16.211)	Time 0.92
# Epoch: [8][30/36]	Loss -5.8219 (-5.3916)	Accuracy 11.719 (15.121)	Time 0.84
# Epoch: 8 | Forget Set Accuracy: 0.097 | Retain Set Accuracy: 0.889 | Test Set Accuracy: 0.841
#
# Epoch: [9][0/36]	Loss -5.6950 (-5.6950)	Accuracy 15.625 (15.625)	Time 0.39
# Epoch: [9][15/36]	Loss -7.3500 (-6.9267)	Accuracy 6.250 (9.326)	Time 1.07
# Epoch: [9][30/36]	Loss -7.9645 (-7.2822)	Accuracy 3.125 (7.182)	Time 0.90
# Epoch: 9 | Forget Set Accuracy: 0.036 | Retain Set Accuracy: 0.868 | Test Set Accuracy: 0.826
#
# Epoch: [10][0/36]	Loss -8.4826 (-8.4826)	Accuracy 3.906 (3.906)	Time 0.14
# Epoch: [10][15/36]	Loss -9.5415 (-8.9058)	Accuracy 0.000 (2.783)	Time 0.93
# Epoch: [10][30/36]	Loss -10.2077 (-9.4474)	Accuracy 0.000 (2.293)	Time 0.85
# Epoch: 10 | Forget Set Accuracy: 0.009 | Retain Set Accuracy: 0.844 | Test Set Accuracy: 0.805
#
# Epoch: [11][0/36]	Loss -10.8101 (-10.8101)	Accuracy 0.781 (0.781)	Time 0.18
# Epoch: [11][15/36]	Loss -12.0651 (-11.3099)	Accuracy 1.562 (0.977)	Time 0.92
# Epoch: [11][30/36]	Loss -12.8866 (-11.8695)	Accuracy 0.781 (0.781)	Time 0.88
# Epoch: 11 | Forget Set Accuracy: 0.003 | Retain Set Accuracy: 0.808 | Test Set Accuracy: 0.776
#
# Epoch: [12][0/36]	Loss -13.9490 (-13.9490)	Accuracy 0.781 (0.781)	Time 0.21
# Epoch: [12][15/36]	Loss -14.6351 (-14.0251)	Accuracy 0.000 (0.244)	Time 0.92
# Epoch: [12][30/36]	Loss -16.1199 (-14.5863)	Accuracy 0.000 (0.227)	Time 0.85
# Epoch: 12 | Forget Set Accuracy: 0.001 | Retain Set Accuracy: 0.761 | Test Set Accuracy: 0.737
#
# ==================================================    CLASS 1
#
# Class to forget for this run: 1
#
# -------------------------    RUN 1
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.97 | Retain Set Accuracy: 0.92
# Epoch: [1][0/36]	Loss -0.0277 (-0.0277)	Accuracy 100.000 (100.000)	Time 0.12
# Epoch: [1][15/36]	Loss -0.0615 (-0.0979)	Accuracy 98.438 (96.729)	Time 0.89
# Epoch: [1][30/36]	Loss -0.0475 (-0.1131)	Accuracy 98.438 (96.043)	Time 0.86
# Epoch: 1 | Forget Set Accuracy: 0.948 | Retain Set Accuracy: 0.921 | Test Set Accuracy: 0.864
#
# Epoch: [2][0/36]	Loss -0.1105 (-0.1105)	Accuracy 95.312 (95.312)	Time 0.34
# Epoch: [2][15/36]	Loss -0.2212 (-0.1719)	Accuracy 92.188 (93.945)	Time 0.91
# Epoch: [2][30/36]	Loss -0.1794 (-0.1769)	Accuracy 95.312 (93.674)	Time 0.84
# Epoch: 2 | Forget Set Accuracy: 0.914 | Retain Set Accuracy: 0.919 | Test Set Accuracy: 0.862
#
# Epoch: [3][0/36]	Loss -0.2265 (-0.2265)	Accuracy 90.625 (90.625)	Time 0.16
# Epoch: [3][15/36]	Loss -0.2545 (-0.2635)	Accuracy 91.406 (90.723)	Time 0.90
# Epoch: [3][30/36]	Loss -0.3855 (-0.3113)	Accuracy 88.281 (89.214)	Time 0.85
# Epoch: 3 | Forget Set Accuracy: 0.848 | Retain Set Accuracy: 0.918 | Test Set Accuracy: 0.856
#
# Epoch: [4][0/36]	Loss -0.4496 (-0.4496)	Accuracy 85.156 (85.156)	Time 0.15
# Epoch: [4][15/36]	Loss -0.4841 (-0.4876)	Accuracy 84.375 (83.252)	Time 0.88
# Epoch: [4][30/36]	Loss -0.5268 (-0.5785)	Accuracy 82.031 (80.872)	Time 0.87
# Epoch: 4 | Forget Set Accuracy: 0.719 | Retain Set Accuracy: 0.912 | Test Set Accuracy: 0.842
#
# Epoch: [5][0/36]	Loss -1.1069 (-1.1069)	Accuracy 64.844 (64.844)	Time 0.18
# Epoch: [5][15/36]	Loss -1.2175 (-1.0122)	Accuracy 62.500 (69.043)	Time 0.91
# Epoch: [5][30/36]	Loss -1.8348 (-1.2394)	Accuracy 52.344 (64.415)	Time 0.85
# Epoch: 5 | Forget Set Accuracy: 0.523 | Retain Set Accuracy: 0.902 | Test Set Accuracy: 0.820
#
# Epoch: [6][0/36]	Loss -2.2903 (-2.2903)	Accuracy 46.875 (46.875)	Time 0.14
# Epoch: [6][15/36]	Loss -2.5640 (-2.2107)	Accuracy 45.312 (47.803)	Time 0.88
# Epoch: [6][30/36]	Loss -3.1677 (-2.5855)	Accuracy 37.500 (42.767)	Time 0.86
# Epoch: 6 | Forget Set Accuracy: 0.293 | Retain Set Accuracy: 0.882 | Test Set Accuracy: 0.787
#
# Epoch: [7][0/36]	Loss -3.8434 (-3.8434)	Accuracy 28.906 (28.906)	Time 0.28
# ...
# Epoch: [4][30/36]	Loss -0.9186 (-0.7622)	Accuracy 77.344 (76.915)	Time 0.85
# Epoch: 4 | Forget Set Accuracy: 0.695 | Retain Set Accuracy: 0.918 | Test Set Accuracy: 0.838
#
# Epoch: [5][0/36]	Loss -1.3757 (-1.3757)	Accuracy 66.406 (66.406)	Time 0.12
# Epoch: [5][15/36]	Loss -1.2209 (-1.1296)	Accuracy 64.844 (67.578)	Time 0.89
# Epoch: [5][30/36]	Loss -1.8307 (-1.2897)	Accuracy 57.812 (65.020)	Time 0.85
# Epoch: 5 | Forget Set Accuracy: 0.545 | Retain Set Accuracy: 0.912 | Test Set Accuracy: 0.820
#
# Epoch: [6][0/36]	Loss -1.9873 (-1.9873)	Accuracy 56.250 (56.250)	Time 0.13
# Epoch: [6][15/36]	Loss -2.3020 (-2.1847)	Accuracy 47.656 (49.951)	Time 0.89
# Epoch: [6][30/36]	Loss -2.6857 (-2.3808)	Accuracy 43.750 (47.429)	Time 0.85
# Epoch: 6 | Forget Set Accuracy: 0.357 | Retain Set Accuracy: 0.897 | Test Set Accuracy: 0.799
#
# Epoch: [7][0/36]	Loss -3.8556 (-3.8556)	Accuracy 28.906 (28.906)	Time 0.19
# Epoch: [7][15/36]	Loss -4.1856 (-3.7023)	Accuracy 24.219 (31.152)	Time 0.90
# Epoch: [7][30/36]	Loss -5.1121 (-4.0622)	Accuracy 26.562 (28.402)	Time 0.85
# Epoch: 7 | Forget Set Accuracy: 0.195 | Retain Set Accuracy: 0.877 | Test Set Accuracy: 0.769
#
# Epoch: [8][0/36]	Loss -5.0428 (-5.0428)	Accuracy 19.531 (19.531)	Time 0.11
# Epoch: [8][15/36]	Loss -5.8787 (-5.7114)	Accuracy 17.188 (16.992)	Time 0.89
# Epoch: [8][30/36]	Loss -7.7640 (-6.3096)	Accuracy 5.469 (13.710)	Time 0.85
# Epoch: 8 | Forget Set Accuracy: 0.084 | Retain Set Accuracy: 0.847 | Test Set Accuracy: 0.741
#
# Epoch: [9][0/36]	Loss -7.6932 (-7.6932)	Accuracy 10.156 (10.156)	Time 0.18
# Epoch: [9][15/36]	Loss -9.4428 (-8.5637)	Accuracy 6.250 (7.129)	Time 0.88
# Epoch: [9][30/36]	Loss -10.0169 (-9.1015)	Accuracy 1.562 (5.897)	Time 0.90
# Epoch: 9 | Forget Set Accuracy: 0.030 | Retain Set Accuracy: 0.809 | Test Set Accuracy: 0.712
#
# Epoch: [10][0/36]	Loss -10.9244 (-10.9244)	Accuracy 3.906 (3.906)	Time 0.14
# Epoch: [10][15/36]	Loss -12.5275 (-11.5266)	Accuracy 0.000 (2.246)	Time 0.89
# Epoch: [10][30/36]	Loss -13.5026 (-12.2527)	Accuracy 1.562 (1.537)	Time 0.84
# Epoch: 10 | Forget Set Accuracy: 0.006 | Retain Set Accuracy: 0.758 | Test Set Accuracy: 0.684
#
# Epoch: [11][0/36]	Loss -15.2681 (-15.2681)	Accuracy 0.000 (0.000)	Time 0.13
# Epoch: [11][15/36]	Loss -15.3337 (-15.0314)	Accuracy 0.000 (0.537)	Time 0.91
# Epoch: [11][30/36]	Loss -17.1234 (-15.6924)	Accuracy 0.000 (0.353)	Time 0.89
# Epoch: 11 | Forget Set Accuracy: 0.000 | Retain Set Accuracy: 0.697 | Test Set Accuracy: 0.642
#
# Epoch: [12][0/36]	Loss -16.8762 (-16.8762)	Accuracy 0.781 (0.781)	Time 0.21
# Epoch: [12][15/36]	Loss -19.1862 (-18.2605)	Accuracy 0.000 (0.098)	Time 0.91
# Epoch: [12][30/36]	Loss -20.8154 (-19.1168)	Accuracy 0.000 (0.076)	Time 0.85
# Epoch: 12 | Forget Set Accuracy: 0.000 | Retain Set Accuracy: 0.623 | Test Set Accuracy: 0.590
#
# -------------------------    RUN 6
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.95 | Retain Set Accuracy: 0.92
# Epoch: [1][0/36]	Loss -0.1717 (-0.1717)	Accuracy 95.312 (95.312)	Time 0.08
# Epoch: [1][15/36]	Loss -0.1576 (-0.1465)	Accuracy 95.312 (95.459)	Time 0.85
# Epoch: [1][30/36]	Loss -0.2699 (-0.1664)	Accuracy 92.969 (94.808)	Time 0.84
# Epoch: 1 | Forget Set Accuracy: 0.926 | Retain Set Accuracy: 0.922 | Test Set Accuracy: 0.862
#
# Epoch: [2][0/36]	Loss -0.2551 (-0.2551)	Accuracy 93.750 (93.750)	Time 0.13
# Epoch: [2][15/36]	Loss -0.3182 (-0.2606)	Accuracy 89.844 (92.188)	Time 0.88
# Epoch: [2][30/36]	Loss -0.2605 (-0.2678)	Accuracy 90.625 (91.457)	Time 0.85
# Epoch: 2 | Forget Set Accuracy: 0.889 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.858
#
# Epoch: [3][0/36]	Loss -0.3440 (-0.3440)	Accuracy 89.062 (89.062)	Time 0.16
# Epoch: [3][15/36]	Loss -0.4814 (-0.3648)	Accuracy 89.062 (88.379)	Time 0.91
# Epoch: [3][30/36]	Loss -0.5560 (-0.4275)	Accuracy 80.469 (86.290)	Time 0.85
# Epoch: 3 | Forget Set Accuracy: 0.819 | Retain Set Accuracy: 0.922 | Test Set Accuracy: 0.850
#
# Epoch: [4][0/36]	Loss -0.7114 (-0.7114)	Accuracy 77.344 (77.344)	Time 0.20
# Epoch: [4][15/36]	Loss -0.6904 (-0.6512)	Accuracy 82.812 (79.492)	Time 0.93
# Epoch: [4][30/36]	Loss -0.6837 (-0.7410)	Accuracy 80.469 (77.722)	Time 0.92
# Epoch: 4 | Forget Set Accuracy: 0.697 | Retain Set Accuracy: 0.920 | Test Set Accuracy: 0.838
#
# Epoch: [5][0/36]	Loss -1.1173 (-1.1173)	Accuracy 67.969 (67.969)	Time 0.10
# Epoch: [5][15/36]	Loss -1.1003 (-1.2136)	Accuracy 72.656 (66.895)	Time 0.85
# Epoch: [5][30/36]	Loss -1.6050 (-1.3491)	Accuracy 57.812 (64.214)	Time 0.87
# Epoch: 5 | Forget Set Accuracy: 0.537 | Retain Set Accuracy: 0.912 | Test Set Accuracy: 0.819
#
# Epoch: [6][0/36]	Loss -1.9749 (-1.9749)	Accuracy 54.688 (54.688)	Time 0.19
# Epoch: [6][15/36]	Loss -2.5958 (-2.1157)	Accuracy 44.531 (50.342)	Time 0.91
# Epoch: [6][30/36]	Loss -2.9271 (-2.3848)	Accuracy 38.281 (46.900)	Time 0.87
# Epoch: 6 | Forget Set Accuracy: 0.352 | Retain Set Accuracy: 0.897 | Test Set Accuracy: 0.799
#
# Epoch: [7][0/36]	Loss -3.2488 (-3.2488)	Accuracy 36.719 (36.719)	Time 0.14
# Epoch: [7][15/36]	Loss -3.9048 (-3.7160)	Accuracy 26.562 (32.080)	Time 0.88
# Epoch: [7][30/36]	Loss -4.5520 (-4.0354)	Accuracy 26.562 (29.032)	Time 0.84
# Epoch: 7 | Forget Set Accuracy: 0.195 | Retain Set Accuracy: 0.876 | Test Set Accuracy: 0.769
#
# Epoch: [8][0/36]	Loss -5.9189 (-5.9189)	Accuracy 17.188 (17.188)	Time 0.09
# Epoch: [8][15/36]	Loss -6.7646 (-5.9129)	Accuracy 16.406 (16.162)	Time 0.89
# Epoch: [8][30/36]	Loss -8.1431 (-6.3921)	Accuracy 7.031 (13.962)	Time 0.84
# Epoch: 8 | Forget Set Accuracy: 0.084 | Retain Set Accuracy: 0.848 | Test Set Accuracy: 0.740
#
# Epoch: [9][0/36]	Loss -7.9293 (-7.9293)	Accuracy 10.156 (10.156)	Time 0.20
# Epoch: [9][15/36]	Loss -8.8379 (-8.5072)	Accuracy 3.906 (6.152)	Time 0.96
# Epoch: [9][30/36]	Loss -10.6069 (-9.1496)	Accuracy 1.562 (4.990)	Time 0.85
# Epoch: 9 | Forget Set Accuracy: 0.028 | Retain Set Accuracy: 0.807 | Test Set Accuracy: 0.713
#
# Epoch: [10][0/36]	Loss -11.1753 (-11.1753)	Accuracy 2.344 (2.344)	Time 0.14
# Epoch: [10][15/36]	Loss -12.5640 (-11.6252)	Accuracy 0.000 (2.002)	Time 0.87
# Epoch: [10][30/36]	Loss -13.2532 (-12.2488)	Accuracy 0.781 (1.689)	Time 0.84
# Epoch: 10 | Forget Set Accuracy: 0.006 | Retain Set Accuracy: 0.758 | Test Set Accuracy: 0.683
#
# Epoch: [11][0/36]	Loss -13.4038 (-13.4038)	Accuracy 2.344 (2.344)	Time 0.12
# Epoch: [11][15/36]	Loss -16.8960 (-14.8121)	Accuracy 0.781 (0.586)	Time 0.86
# Epoch: [11][30/36]	Loss -17.3619 (-15.5478)	Accuracy 0.000 (0.454)	Time 0.84
# Epoch: 11 | Forget Set Accuracy: 0.002 | Retain Set Accuracy: 0.695 | Test Set Accuracy: 0.640
#
# Epoch: [12][0/36]	Loss -17.4508 (-17.4508)	Accuracy 0.781 (0.781)	Time 0.16
# Epoch: [12][15/36]	Loss -19.0497 (-18.4128)	Accuracy 0.000 (0.098)	Time 0.94
# Epoch: [12][30/36]	Loss -19.6226 (-19.1339)	Accuracy 0.000 (0.050)	Time 0.85
# Epoch: 12 | Forget Set Accuracy: 0.000 | Retain Set Accuracy: 0.621 | Test Set Accuracy: 0.587
#
# -------------------------    RUN 7
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.95 | Retain Set Accuracy: 0.92
# Epoch: [1][0/36]	Loss -0.0933 (-0.0933)	Accuracy 96.094 (96.094)	Time 0.07
# Epoch: [1][15/36]	Loss -0.1988 (-0.1685)	Accuracy 95.312 (94.775)	Time 0.88
# Epoch: [1][30/36]	Loss -0.1389 (-0.1792)	Accuracy 95.312 (94.103)	Time 0.85
# Epoch: 1 | Forget Set Accuracy: 0.931 | Retain Set Accuracy: 0.924 | Test Set Accuracy: 0.862
#
# Epoch: [2][0/36]	Loss -0.1964 (-0.1964)	Accuracy 95.312 (95.312)	Time 0.23
# Epoch: [2][15/36]	Loss -0.2164 (-0.2547)	Accuracy 92.188 (92.188)	Time 0.90
# Epoch: [2][30/36]	Loss -0.3156 (-0.2748)	Accuracy 92.188 (91.633)	Time 0.86
# Epoch: 2 | Forget Set Accuracy: 0.887 | Retain Set Accuracy: 0.926 | Test Set Accuracy: 0.859
#
# Epoch: [3][0/36]	Loss -0.3984 (-0.3984)	Accuracy 85.938 (85.938)	Time 0.24
# Epoch: [3][15/36]	Loss -0.5038 (-0.3958)	Accuracy 85.938 (86.963)	Time 0.90
# Epoch: [3][30/36]	Loss -0.5498 (-0.4351)	Accuracy 83.594 (86.341)	Time 0.90
# Epoch: 3 | Forget Set Accuracy: 0.817 | Retain Set Accuracy: 0.925 | Test Set Accuracy: 0.850
#
# Epoch: [4][0/36]	Loss -0.6487 (-0.6487)	Accuracy 79.688 (79.688)	Time 0.17
# Epoch: [4][15/36]	Loss -0.6828 (-0.7000)	Accuracy 80.469 (79.150)	Time 0.89
# Epoch: [4][30/36]	Loss -1.1352 (-0.7811)	Accuracy 67.188 (76.714)	Time 0.84
# Epoch: 4 | Forget Set Accuracy: 0.696 | Retain Set Accuracy: 0.918 | Test Set Accuracy: 0.838
#
# Epoch: [5][0/36]	Loss -0.9640 (-0.9640)	Accuracy 75.000 (75.000)	Time 0.21
# Epoch: [5][15/36]	Loss -1.1866 (-1.1949)	Accuracy 65.625 (66.992)	Time 0.94
# Epoch: [5][30/36]	Loss -1.7190 (-1.3610)	Accuracy 58.594 (63.432)	Time 0.90
# Epoch: 5 | Forget Set Accuracy: 0.546 | Retain Set Accuracy: 0.913 | Test Set Accuracy: 0.819
#
# Epoch: [6][0/36]	Loss -1.7896 (-1.7896)	Accuracy 54.688 (54.688)	Time 0.29
# Epoch: [6][15/36]	Loss -1.9622 (-2.0532)	Accuracy 55.469 (51.611)	Time 0.91
# Epoch: [6][30/36]	Loss -3.0079 (-2.3859)	Accuracy 39.844 (47.253)	Time 0.89
# Epoch: 6 | Forget Set Accuracy: 0.361 | Retain Set Accuracy: 0.896 | Test Set Accuracy: 0.798
#
# Epoch: [7][0/36]	Loss -3.9180 (-3.9180)	Accuracy 26.562 (26.562)	Time 0.18
# Epoch: [7][15/36]	Loss -3.9925 (-3.6734)	Accuracy 28.906 (31.250)	Time 0.91
# Epoch: [7][30/36]	Loss -4.4152 (-4.0479)	Accuracy 23.438 (28.150)	Time 0.86
# Epoch: 7 | Forget Set Accuracy: 0.195 | Retain Set Accuracy: 0.877 | Test Set Accuracy: 0.769
#
# Epoch: [8][0/36]	Loss -5.2432 (-5.2432)	Accuracy 17.969 (17.969)	Time 0.21
# Epoch: [8][15/36]	Loss -6.7439 (-5.7421)	Accuracy 16.406 (16.895)	Time 0.98
# Epoch: [8][30/36]	Loss -7.3163 (-6.2969)	Accuracy 9.375 (14.441)	Time 0.85
# Epoch: 8 | Forget Set Accuracy: 0.082 | Retain Set Accuracy: 0.847 | Test Set Accuracy: 0.741
#
# Epoch: [9][0/36]	Loss -7.8090 (-7.8090)	Accuracy 7.812 (7.812)	Time 0.11
# Epoch: [9][15/36]	Loss -9.8226 (-8.6017)	Accuracy 3.125 (5.811)	Time 1.10
# Epoch: [9][30/36]	Loss -10.5548 (-9.0982)	Accuracy 1.562 (5.116)	Time 0.90
# Epoch: 9 | Forget Set Accuracy: 0.026 | Retain Set Accuracy: 0.807 | Test Set Accuracy: 0.712
#
# Epoch: [10][0/36]	Loss -10.0221 (-10.0221)	Accuracy 0.781 (0.781)	Time 0.15
# Epoch: [10][15/36]	Loss -12.8381 (-11.4445)	Accuracy 0.781 (2.246)	Time 0.89
# Epoch: [10][30/36]	Loss -13.8116 (-12.1548)	Accuracy 1.562 (1.915)	Time 0.92
# Epoch: 10 | Forget Set Accuracy: 0.008 | Retain Set Accuracy: 0.757 | Test Set Accuracy: 0.683
#
# Epoch: [11][0/36]	Loss -14.9383 (-14.9383)	Accuracy 0.000 (0.000)	Time 0.19
# Epoch: [11][15/36]	Loss -16.3487 (-15.2195)	Accuracy 0.000 (0.244)	Time 0.90
# Epoch: [11][30/36]	Loss -17.3568 (-15.7474)	Accuracy 0.000 (0.202)	Time 0.89
# Epoch: 11 | Forget Set Accuracy: 0.001 | Retain Set Accuracy: 0.693 | Test Set Accuracy: 0.640
#
# Epoch: [12][0/36]	Loss -18.3033 (-18.3033)	Accuracy 0.000 (0.000)	Time 0.21
# Epoch: [12][15/36]	Loss -18.9717 (-18.3488)	Accuracy 0.781 (0.098)	Time 0.96
# Epoch: [12][30/36]	Loss -21.1561 (-19.1551)	Accuracy 0.000 (0.050)	Time 0.85
# Epoch: 12 | Forget Set Accuracy: 0.000 | Retain Set Accuracy: 0.620 | Test Set Accuracy: 0.586
#
# -------------------------    RUN 8
#
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# Dataset information: CIFAR-10	 45000 images for training 	 5000 images for validation
# 10000 images for testing	 no normalize applied in data_transform
# Training data augmentation = randomcrop(32,4) + randomhorizontalflip
# datasets length:  4500 40500
# Baseline | Forget Set Accuracy: 0.95 | Retain Set Accuracy: 0.92
# Epoch: [1][0/36]	Loss -0.1081 (-0.1081)	Accuracy 96.875 (96.875)	Time 0.07
# Epoch: [1][15/36]	Loss -0.1255 (-0.1757)	Accuracy 95.312 (94.238)	Time 0.86
# Epoch: [1][30/36]	Loss -0.2005 (-0.1690)	Accuracy 93.750 (94.304)	Time 0.85
# Epoch: 1 | Forget Set Accuracy: 0.930 | Retain Set Accuracy: 0.924 | Test Set Accuracy: 0.862
#
# Epoch: [2][0/36]	Loss -0.2667 (-0.2667)	Accuracy 92.969 (92.969)	Time 0.11
# Epoch: [2][15/36]	Loss -0.2460 (-0.2243)	Accuracy 89.844 (92.871)	Time 0.86
# Epoch: [2][30/36]	Loss -0.2493 (-0.2475)	Accuracy 92.969 (92.112)	Time 0.87
# Epoch: 2 | Forget Set Accuracy: 0.894 | Retain Set Accuracy: 0.924 | Test Set Accuracy: 0.858
#
# Epoch: [3][0/36]	Loss -0.2752 (-0.2752)	Accuracy 91.406 (91.406)	Time 0.13
# Epoch: [3][15/36]	Loss -0.3928 (-0.3864)	Accuracy 87.500 (87.500)	Time 0.99
# Epoch: [3][30/36]	Loss -0.4415 (-0.4477)	Accuracy 87.500 (86.114)	Time 0.85
# Epoch: 3 | Forget Set Accuracy: 0.821 | Retain Set Accuracy: 0.922 | Test Set Accuracy: 0.850
#
# Epoch: [4][0/36]	Loss -0.4998 (-0.4998)	Accuracy 85.938 (85.938)	Time 0.16
# Epoch: [4][15/36]	Loss -0.6657 (-0.6618)	Accuracy 78.125 (80.029)	Time 0.92
# Epoch: [4][30/36]	Loss -1.0068 (-0.7486)	Accuracy 75.781 (77.394)	Time 0.86
# Epoch: 4 | Forget Set Accuracy: 0.697 | Retain Set Accuracy: 0.920 | Test Set Accuracy: 0.839
#
# Epoch: [5][0/36]	Loss -0.9785 (-0.9785)	Accuracy 67.969 (67.969)	Time 0.31
# Epoch: [5][15/36]	Loss -1.5204 (-1.2444)	Accuracy 60.156 (66.211)	Time 0.91
# Epoch: [5][30/36]	Loss -1.9959 (-1.3462)	Accuracy 48.438 (63.609)	Time 0.89
# Epoch: 5 | Forget Set Accuracy: 0.547 | Retain Set Accuracy: 0.910 | Test Set Accuracy: 0.819
#
# Epoch: [6][0/36]	Loss -1.6057 (-1.6057)	Accuracy 56.250 (56.250)	Time 0.34
# Epoch: [6][15/36]	Loss -2.4340 (-2.0631)	Accuracy 46.094 (51.025)	Time 0.96
# Epoch: [6][30/36]	Loss -2.8596 (-2.4115)	Accuracy 28.906 (45.917)	Time 0.87
# Epoch: 6 | Forget Set Accuracy: 0.357 | Retain Set Accuracy: 0.895 | Test Set Accuracy: 0.797
#
# Epoch: [7][0/36]	Loss -3.5481 (-3.5481)	Accuracy 33.594 (33.594)	Time 0.38
# Epoch: [7][15/36]	Loss -4.5647 (-3.6027)	Accuracy 25.000 (32.422)	Time 0.94
# Epoch: [7][30/36]	Loss -5.0526 (-4.0816)	Accuracy 26.562 (28.075)	Time 0.92
# Epoch: 7 | Forget Set Accuracy: 0.193 | Retain Set Accuracy: 0.874 | Test Set Accuracy: 0.768
#
# Epoch: [8][0/36]	Loss -5.3678 (-5.3678)	Accuracy 15.625 (15.625)	Time 0.32
# Epoch: [8][15/36]	Loss -6.2993 (-5.9422)	Accuracy 16.406 (15.674)	Time 0.90
# Epoch: [8][30/36]	Loss -7.7453 (-6.4064)	Accuracy 6.250 (13.432)	Time 0.93
# Epoch: 8 | Forget Set Accuracy: 0.080 | Retain Set Accuracy: 0.846 | Test Set Accuracy: 0.740
#
# Epoch: [9][0/36]	Loss -8.0023 (-8.0023)	Accuracy 8.594 (8.594)	Time 0.37
# Epoch: [9][15/36]	Loss -9.1761 (-8.6163)	Accuracy 5.469 (6.152)	Time 0.86
# Epoch: [9][30/36]	Loss -10.8914 (-9.2872)	Accuracy 2.344 (5.091)	Time 0.85
# Epoch: 9 | Forget Set Accuracy: 0.025 | Retain Set Accuracy: 0.807 | Test Set Accuracy: 0.712
#
# Epoch: [10][0/36]	Loss -11.5777 (-11.5777)	Accuracy 1.562 (1.562)	Time 0.39
# Epoch: [10][15/36]	Loss -12.2294 (-11.6634)	Accuracy 1.562 (1.758)	Time 0.91
# Epoch: [10][30/36]	Loss -13.7494 (-12.3080)	Accuracy 0.781 (1.462)	Time 0.87
# Epoch: 10 | Forget Set Accuracy: 0.008 | Retain Set Accuracy: 0.756 | Test Set Accuracy: 0.683
#
# Epoch: [11][0/36]	Loss -14.4284 (-14.4284)	Accuracy 0.000 (0.000)	Time 0.37
# Epoch: [11][15/36]	Loss -15.5574 (-15.0896)	Accuracy 0.000 (0.488)	Time 0.98
# Epoch: [11][30/36]	Loss -17.2650 (-15.7012)	Accuracy 0.000 (0.378)	Time 0.93
# Epoch: 11 | Forget Set Accuracy: 0.002 | Retain Set Accuracy: 0.694 | Test Set Accuracy: 0.641
#
# Epoch: [12][0/36]	Loss -17.4524 (-17.4524)	Accuracy 0.000 (0.000)	Time 0.40
# Epoch: [12][15/36]	Loss -19.0717 (-18.6123)	Accuracy 0.000 (0.098)	Time 0.98
# Epoch: [12][30/36]	Loss -20.1397 (-19.2309)	Accuracy 0.000 (0.076)	Time 0.89
